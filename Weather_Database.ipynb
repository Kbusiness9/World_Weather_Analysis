# %% [markdown]
# # Challenge PART 1 get the weather description and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitudes and longitudes combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# %%
# Ad the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for a holding the cities
cities = []

# Identify nearest city for each latitude and longtitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique then add it to cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 631

# %%
# Import the request library
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = f"httpp://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = f'{url}&q={city.replace(" ","+")}'
    # Log the url record and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the max tem, humidity, and cloudiness
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather["weather"][0]["description"]
            try:
                city_rain_inches = city_weather["rain"]["1h"]
            except KeyError:
                city_rain_inches = 0
            try:
                city_snow_inches = city_weather["rain"]["1h"]
            except KeyError:
                city_snow_inches = 0
            
            # Append the city information into city_data
            city_data.append(
            {
                "City": city, 
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Current Description": city_weather_description,
                "Rain (inches)": city_rain_inches,
                "Snow (inches)": city_snow_inches,
                "Humidity": city_humidity, 
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country
            
            })
    except: 
            print("City not found. Skipping...")
            pass

    # Indiciate that the Data Loading is complete
    print("-" * 20)
    print("Data Retrieval Complete")
    print("-" *20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 1 | axams
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 1 | palabuhanratu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 1 | saint-philippe
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 1 | qixia
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 1 | tacoronte
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 1 | yellowknife
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 1 | nikolskoye
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 1 | sola
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 1 | tiksi
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 1 | ambon
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 1 | hobart
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 1 | rikitea
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 1 | busselton
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 1 | punta arenas
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 1 | tateyama
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 1 | mawlaik
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 1 | san quintin
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 1 | new norfolk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 1 | te anau
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 1 | port macquarie
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 1 | lavrentiya
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 1 | nome
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 1 | kodiak
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 1 | qaanaaq
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 1 | shenjiamen
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 1 | saint george
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 1 | cidreira
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 1 | harper
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set 1 | egvekinot
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 31 of Set 1 | mayo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 32 of Set 1 | scarborough
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 33 of Set 1 | malwan
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 34 of Set 1 | bengkulu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 35 of Set 1 | oksfjord
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 36 of Set 1 | bahawalpur
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 37 of Set 1 | jamestown
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 38 of Set 1 | ushuaia
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 40 of Set 1 | avera
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 41 of Set 1 | mataura
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 42 of Set 1 | vaini
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 43 of Set 1 | iqaluit
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 44 of Set 1 | sur
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 45 of Set 1 | toyooka
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 46 of Set 1 | caravelas
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 47 of Set 1 | atuona
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 48 of Set 1 | lensk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 49 of Set 1 | mogocha
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 50 of Set 1 | upernavik
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 1 of Set 2 | mujiayingzi
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 2 | gravelbourg
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 2 | katsuura
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 2 | faya
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 2 | bredasdorp
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 2 | ponta do sol
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 2 | carnarvon
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 2 | lesnoye
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 2 | kampene
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 2 | nabire
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 2 | doha
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 2 | albany
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 2 | nazas
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 2 | castro
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 2 | cape town
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 2 | hasaki
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 2 | beaverlodge
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 2 | culebra
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 2 | butaritari
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 2 | la rioja
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 2 | paamiut
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 2 | kavaratti
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 2 | hay river
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 2 | hilo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 2 | poya
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 2 | rio grande
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 8 | chabahar
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 8 | mackay
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 8 | cumra
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 8 | cayenne
# City not found. Skipping...
# --------------------
# ...
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 11 | sibolga
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 11 | jiuquan
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 11 | havre-saint-pierre
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 11 | tongren
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 11 | abu zabad
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 11 | obo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 11 | chirongui
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 11 | george
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 11 | norman wells
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 11 | hanstholm
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 11 | muscat
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 11 | grand-santi
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 11 | storebo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 11 | bondo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 11 | dos hermanas
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set 11 | cuamba
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 31 of Set 11 | axim
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 32 of Set 11 | eureka
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 33 of Set 11 | margate
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 34 of Set 11 | giyani
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 35 of Set 11 | manzhouli
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 36 of Set 11 | erzin
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 37 of Set 11 | rehoboth
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 38 of Set 11 | grindavik
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 39 of Set 11 | bathsheba
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 40 of Set 11 | brusyliv
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 41 of Set 11 | murashi
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 42 of Set 11 | solsvik
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 43 of Set 11 | bairiki
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 44 of Set 11 | mongo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 45 of Set 11 | mehamn
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 46 of Set 11 | arcata
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 47 of Set 11 | bac lieu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 48 of Set 11 | verkhnevilyuysk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 49 of Set 11 | walvis bay
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 50 of Set 11 | chicama
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 1 of Set 12 | sabzevar
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 12 | portel
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 12 | zhifang
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 12 | katete
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 12 | zhigansk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 12 | port hedland
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 12 | bitung
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 12 | nuuk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 12 | kuito
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 12 | north platte
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 12 | purranque
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 12 | okha
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 12 | vuktyl
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 12 | haldia
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 12 | ust-barguzin
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 12 | flin flon
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 12 | artyk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 12 | sao felix do xingu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 12 | rock sound
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 12 | strand
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 12 | san policarpo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 12 | thongwa
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 12 | teya
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 12 | samalaeulu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 12 | paramonga
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 12 | kargasok
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 12 | darab
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 12 | shilka
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 12 | parker
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set 12 | le port
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 31 of Set 12 | znamenskoye
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 32 of Set 12 | meulaboh
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 33 of Set 12 | port augusta
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 34 of Set 12 | thayetmyo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 35 of Set 12 | kawalu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 36 of Set 12 | beruwala
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 37 of Set 12 | oktyabrskiy
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 38 of Set 12 | synya
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 39 of Set 12 | yar-sale
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 40 of Set 12 | kutum
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 41 of Set 12 | paka
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 42 of Set 12 | aflu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 43 of Set 12 | ogden
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 44 of Set 12 | shar
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 45 of Set 12 | portadown
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 46 of Set 12 | sayat
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 47 of Set 12 | mitsamiouli
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 48 of Set 12 | asau
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 49 of Set 12 | san buenaventura
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 50 of Set 12 | capreol
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 1 of Set 13 | porbandar
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 13 | fairbanks
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 13 | westport
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 13 | puerto narino
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 13 | saint-augustin
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 13 | kango
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 13 | sayyan
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 13 | qui nhon
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 13 | banda aceh
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 13 | midland
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 13 | boyolangu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 13 | launceston
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 13 | laurel
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 13 | razole
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 13 | katiola
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 13 | kapit
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 13 | virginia beach
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 13 | itarema
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 13 | wukari
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 13 | anshun
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 13 | mapiripan
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 13 | thinadhoo
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 13 | indian head
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 13 | petrov val
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 13 | evensk
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 13 | bonthe
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 13 | conceicao do araguaia
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 13 | kemijarvi
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 13 | lotofaga
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set 13 | tongliao
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 31 of Set 13 | kathmandu
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 0

# %%
# convert list of dictionary to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(100)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_data_df.columns
# Out:
# Index([], dtype='object')

# %%
new_column_order = sorted (city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_data_df.dtypes
# Out:
# Series([], dtype: object)

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head()

# %%
# Create the output file (CSV)
output_data_file = "data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head()
